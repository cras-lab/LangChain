# %% [markdown]
# <a href="https://colab.research.google.com/github/cras-lab/LangChain/blob/main/FirstOpenAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -qU langchain-openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.7/87.7 kB 2.6 MB/s eta 0:00:00

# %%
from langchain_openai import ChatOpenAI
import getpass
OPENAI_API_KEY = getpass.getpass("YOUR KEY: ")

llm = ChatOpenAI(openai_api_key=OPENAI_API_KEY, model_name="gpt-5-nano")
#llm.invoke("It's hot day, I would like to go to the...")

prompt_input = """Tell me 10 topmost Univertsity in the world"""
response = llm.invoke(prompt_input)

print(response.content)
# Out:
# YOUR KEY: ··········
# Do you want the top 10 based on a specific ranking (QS, THE, or ARWU)? Rankings differ slightly by source and year.
#
# Here’s a representative top-10 list that often appears at the very top across major rankings (not strictly ordered by one source):
# 1) MIT (Massachusetts Institute of Technology)
# 2) University of Cambridge
# 3) University of Oxford
# 4) Stanford University
# 5) Harvard University
# 6) California Institute of Technology (Caltech)
# 7) Imperial College London
# 8) University of Chicago
# 9) ETH Zurich (Swiss Federal Institute of Technology)
# 10) University College London (UCL)
#
# Note: the exact order and which universities appear in the top 10 can vary by ranking and year. Would you like me to pull the precise top-10 from QS, THE, or ARWU for a specific year?
